# %% [raw]
# # syntax of if else
#
# if(cond1):
#     statement of cond1
# else:
#     statemet of cond2

# %%
# number positive or negative

a=int(input())

if(a>0):
    print("The entered number is",a,"and it is positive")
else:
    print("The entered number is",a,"and it is negative")
# Out:
#  -8
# The entered number is -8 and it is negative

# %%
# Eligible to Vote or not

age=int(input("Enter your age: "))

if(age<18):
    print("You are not eligible to vote.")
else:
    print("You are eligible to vote.")
# Out:
# Enter your age:  18
# You are eligible to vote.

# %% [raw]
# # syntax of if else if
#
# if(cond1):
#     statement of cond1
# else:
#     if(cond2):
#         statement of cond2
#     else:
#         if(cond3):
#             statement of cond3
#         else:
#             default statement

# %%
# number positive or negative

a=int(input())

if(a>0):
    print("The entered number is",a,"and it is positive")
elif(a<0):
    print("The entered number is",a,"and it is negative")
else:
    print("The entered number is",a,"and it is zero")
# Out:
#  6
# The entered number is 6 and it is positive

# %%
# Percentage Calculator

per=float(input())

if(per>=85 and per<=100):
    print("You have scored {} percentage with Distinction".format(per))
elif(per>=60 and per<=84):
    print("First class")
elif(per>=50 and per<=59):
    print("Second class")
elif(per<=49 and per>=35):
    print("Pass")
else:
    print("Fail")
# Out:
#  87
# You have scored 87.0 percentage with Distinction

# %%
""" write aprogram to check the given input forms which triangle
1. Equilateral
2. Isoceles
3. Scalene
4. Invalid Triangle
"""

a=int(input())
b=int(input())
c=int(input())

if(a+b<c or a+c<b or b+c<a):
    print("Invalid Triangle")
else:
    if(a==b and b==c and c==a):
        print("Equilateral Triangle")
    elif(a==b or a==c or b==c):
        print("Isoceles Triangle")
    else:
        print("Scalene Triangle")
