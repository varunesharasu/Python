# %%
name="Varunesh"
place="Erode"

#general printing statement
print(name,place)
print("I am",name,"and i from",place)
# Out:
# Varunesh Erode
# I am Varunesh and i from Erode

# %%
#.formate method

print("My name is {} and i am from {}" .format(name,place))
# Out:
# My name is Varunesh and i am from Erode

# %%
# fstring method

print(f"My name is {name} and i am from {place}")
# Out:
# My name is Varunesh and i am from Erode

# %%
a=input()
b=input()

print("My name is",a)
print("I am from",b)
# Out:
#  Varunesh T
#  Erode
# My name is Varunesh T
# I am from Erode

# %%
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))

print("the sum of",a,"and",b,"is",a+b)

print("The sum of {} and {} is {}".format(a,b,a+b))

print(f"The sum of {a} and {b} is {a+b}")
# Out:
# Enter a number:  5
# Enter a number:  7
# the sum of 5 and 7 is 12
# The sum of 5 and 7 is 12
# The sum of 5 and 7 is 12
